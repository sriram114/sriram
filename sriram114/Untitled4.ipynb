# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
GA=pd.read_csv("C:/Users/ADMIN/Downloads/Admission_Predict_Ver1.1 (1).csv")

# %%
GA
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# ...

# %%
GA.shape
# Out:
# (500, 9)

# %%
GA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
newdataset=GA.drop(['Serial No.','GRE Score','University Rating','LOR','CGPA','Research','Chance of Admit '],axis=1)

# %%
newdataset
# Out:
#      TOEFL Score  SOP
# 0            118  4.5
# 1            107  4.0
# 2            104  3.0
# 3            110  3.5
# 4            103  2.0
# ..           ...  ...
# 495          108  4.5
# 496          117  5.0
# 497          120  4.5
# 498          103  4.0
# 499          113  4.5
#
# [500 rows x 2 columns]

# %%
x=newdataset.iloc[:,0].values.reshape(-1,1)
y=newdataset.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[118],
#        [107],
#        [104],
#        [110],
#        [103],
#        [115],
#        [109],
#        [101],
#        [102],
#        [108],
#        [106],
#        [111],
#        [112],
#        [109],
#        [104],
#        [105],
#        [107],
#        [106],
#        [110],
#        [102],
#        [107],
#        [114],
#        [116],
#        [119],
#        [119],
#        [120],
#        [109],
#        [ 98],
#        [ 93],
#        [ 99],
#        [ 97],
#        [103],
#        [118],
#        [114],
#        [112],
#        [110],
#        [106],
#        [105],
#        [105],
#        [108],
#        [110],
#        [105],
#        [107],
#        [117],
#        [113],
#        [110],
#        [114],
#        [119],
#        [110],
#        [111],
#        [ 98],
#        [100],
#        [116],
#        [112],
#        [110],
#        [103],
#        [102],
#        [ 99],
#        [ 99],
#        [104],
#        [100],
#        [101],
# ...

# %%
y
# Out:
# array([[4.5],
#        [4. ],
#        [3. ],
#        [3.5],
#        [2. ],
#        [4.5],
#        [3. ],
#        [3. ],
#        [2. ],
#        [3.5],
#        [3.5],
#        [4. ],
#        [4. ],
#        [4. ],
#        [3.5],
#        [3.5],
#        [4. ],
#        [4. ],
#        [4. ],
#        [3.5],
#        [3. ],
#        [3. ],
#        [5. ],
#        [5. ],
#        [4. ],
#        [4.5],
#        [4.5],
#        [1.5],
#        [2. ],
#        [1.5],
#        [3. ],
#        [4. ],
#        [3. ],
#        [4. ],
#        [4. ],
#        [5. ],
#        [4. ],
#        [1. ],
#        [3. ],
#        [4. ],
#        [3.5],
#        [2.5],
#        [2.5],
#        [4.5],
#        [4.5],
#        [5. ],
#        [4. ],
#        [4.5],
#        [3.5],
#        [3. ],
#        [2.5],
#        [1.5],
#        [4. ],
#        [4. ],
#        [3. ],
#        [3. ],
#        [2. ],
#        [4. ],
#        [3. ],
#        [2. ],
#        [3. ],
#        [4. ],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('GRE Score')
pt.ylabel('Chance of Admit')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
x_test.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[3.3388756 ],
#        [4.16418126],
#        [3.85469164],
#        [4.37050768],
#        [2.92622278],
#        [3.2357124 ],
#        [2.82305957],
#        [3.75152843],
#        [2.71989636],
#        [3.2357124 ],
#        [3.02938598],
#        [3.13254919],
#        [2.92622278],
#        [3.64836523],
#        [4.47367088],
#        [2.30724353],
#        [3.75152843],
#        [3.3388756 ],
#        [3.54520202],
#        [3.2357124 ],
#        [2.61673315],
#        [3.13254919],
#        [2.82305957],
#        [4.37050768],
#        [3.75152843],
#        [3.75152843],
#        [4.16418126],
#        [2.51356995],
#        [2.71989636],
#        [2.71989636],
#        [3.02938598],
#        [2.61673315],
#        [3.3388756 ],
#        [3.75152843],
#        [3.2357124 ],
#        [2.82305957],
#        [3.54520202],
#        [4.06101805],
#        [2.92622278],
#        [3.13254919],
#        [3.44203881],
#        [4.16418126],
#        [4.37050768],
# ...

# %%
COMP=pd.DataFrame(x_test,columns=['GRE'])

# %%
COMP
# Out:
#      GRE
# 0    106
# 1    114
# 2    111
# 3    116
# 4    102
# ..   ...
# 245  104
# 246   98
# 247  107
# 248  112
# 249  114
#
# [250 rows x 1 columns]

# %%
COMP['Chance of Admit']=y_test

# %%
COMP
# Out:
#      GRE  Chance of Admit
# 0    106              4.0
# 1    114              4.0
# 2    111              2.5
# 3    116              4.5
# 4    102              2.5
# ..   ...              ...
# 245  104              3.0
# 246   98              2.5
# 247  107              2.5
# 248  112              4.0
# 249  114              4.0
#
# [250 rows x 2 columns]

# %%
COMP['Avldata']=y_predict

# %%
COMP
# Out:
#      GRE  Chance of Admit   Avldata
# 0    106              4.0  3.338876
# 1    114              4.0  4.164181
# 2    111              2.5  3.854692
# 3    116              4.5  4.370508
# 4    102              2.5  2.926223
# ..   ...              ...       ...
# 245  104              3.0  3.132549
# 246   98              2.5  2.513570
# 247  107              2.5  3.442039
# 248  112              4.0  3.957855
# 249  114              4.0  4.164181
#
# [250 rows x 3 columns]
